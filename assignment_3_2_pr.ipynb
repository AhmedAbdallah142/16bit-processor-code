# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAbdallah142/16bit-processor-code/blob/main/assignment_3_2_pr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets
# !pip install tensorflow-io
import os
import tarfile
import librosa
import scipy.io
import scipy as sc
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import opendatasets as od
import tensorflow_io as tfio
import IPython.display as ipd
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
import sklearn.metrics as metrics
from glob import glob
from numpy import linalg
from os import listdir
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
#----------------------------------------------------
from tensorflow.keras.regularizers import l1_l2
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import compute_class_weight
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.64.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (6.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.26.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 4.9 MB/s
# Collecting tensorflow-io-gcs-filesystem==0.26.0
#   Downloading tensorflow_io_gcs_filesystem-0.26.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 34.7 MB/s
# Installing collected packages: tensorflow-io-gcs-filesystem, tensorflow-io
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.25.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.25.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.25.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0+zzzcolab20220506162203 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# Successfully installed tensorflow-io-0.26.0 tensorflow-io-gcs-filesystem-0.26.0

# %%
od.download("https://www.kaggle.com/dmitrybabko/speech-emotion-recognition-en")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: ahmedabdallah142
# Your Kaggle Key: ··········
# Downloading speech-emotion-recognition-en.zip to ./speech-emotion-recognition-en
# 100%|██████████| 987M/987M [00:04<00:00, 228MB/s]

# %%
def LoadAudio(dir_path):
    emotions = []
    data=[]

    for audio in os.listdir(dir_path):
        path = dir_path + audio
        temp , sr = librosa.load(path,sr=16000)
        wav, index = librosa.effects.trim(temp, top_db=60)       
        

        if len(wav) > (3*16000):
            wav = wav[:3*16000]
        else:
            padding = (3*16000) - len(wav)
            offset = padding // 2
            wav = np.pad(wav, (offset,3*16000- len(wav) - offset), 'constant') 

        mean = np.mean(wav)
        std = np.std(wav)
        out = np.ones( (len(wav)) ) 
        wav= np.divide((wav - mean),std,out=out, where=std!=0)#normalization & standarization
        
        data.append(wav)
        
        emotion = path.split('_')
        if emotion[2] == 'SAD':
            emotions.append(0)
        elif emotion[2] == 'ANG':
            emotions.append(1)
        elif emotion[2] == 'DIS':
            emotions.append(2)
        elif emotion[2] == 'NEU':
            emotions.append(3)
        elif emotion[2] == 'HAP':
            emotions.append(4)
        elif emotion[2] == 'FEA':
            emotions.append(5)
        else:
            emotions.append(6)
            
    return data,emotions

# %%
data,Labels =  LoadAudio('./speech-emotion-recognition-en/Crema/')
print(len(data))
print(len(Labels))
# Out:
# 7442
# 7442

# %%
train_data, test_data, train_labels, test_labels = train_test_split(data,Labels, test_size=0.30, random_state=42)
train_data,val_data, train_labels, val_labels = train_test_split(train_data,train_labels, test_size=0.05, random_state=42)
print(len(train_data))
print(len(val_data))
print(len(test_data))
# Out:
# 4948
# 261
# 2233

# %%
def mel_spectrogram_features(data):   
    temp = librosa.feature.melspectrogram(y=data, sr=16000, n_mels=128)
    mel_spec_db=librosa.power_to_db(temp, ref=np.max)
    return mel_spec_db

# %%
def extract_mel_spectrogram_features(data):
    set_spectorgram = np.zeros((len(data),128,94)) 
    for i in range(len(data)):
          set_spectorgram[i]= mel_spectrogram_features(data[i])
    return set_spectorgram

# %%
train_set_spectorgram = extract_mel_spectrogram_features(train_data)
val_set_spectorgram   = extract_mel_spectrogram_features(val_data)
test_set_spectorgram  = extract_mel_spectrogram_features(test_data)

# %%
def specAug(data,label):
  dataSize = len(data)
  for i in range(dataSize):
    mask = data[i].mean()
    data = np.append(data,[tfio.audio.freq_mask(data[i], param=mask)],axis=0)
    label.append(label[i])
    data = np.append(data,[tfio.audio.time_mask(data[i], param=mask)],axis=0)
    label.append(label[i])
  return data
train_set_spectorgram = specAug(train_set_spectorgram,train_labels)

# %%
print(len(train_set_spectorgram))
# Out:
# 9896

# %%
freq_mask = tfio.audio.freq_mask(train_set_spectorgram[1], param=25)
time_mask = tfio.audio.time_mask(freq_mask, param=25)

plt.figure()
plt.imshow(freq_mask.numpy())

plt.figure()
plt.imshow(time_mask.numpy())

# %%
train_set_spectorgram = train_set_spectorgram[:,:,:,np.newaxis]
print(train_set_spectorgram.shape)
val_set_spectorgram = val_set_spectorgram[:,:,:,np.newaxis]
print(val_set_spectorgram.shape)
test_set_spectorgram = test_set_spectorgram[:,:,:,np.newaxis]
print(test_set_spectorgram.shape)
# Out:
# (4948, 128, 94, 1)
# (261, 128, 94, 1)
# (2233, 128, 94, 1)

# %%
CNNmodel = Sequential()
CNNmodel.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(train_set_spectorgram.shape[1],train_set_spectorgram.shape[2],1)))
CNNmodel.add(layers.MaxPooling2D((2, 2)))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Conv2D(64, (3, 3), activation='relu'))
CNNmodel.add(layers.MaxPooling2D((2, 2)))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Conv2D(64, (3, 3), activation='relu'))
CNNmodel.add(layers.MaxPooling2D((2, 2)))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Conv2D(64, (3, 3), activation='relu'))
CNNmodel.add(layers.MaxPooling2D((2, 2)))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Conv2D(64, (3, 3), activation='relu'))
CNNmodel.add(layers.Flatten())
CNNmodel.add(layers.Dense(64, activation='relu'))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Dense(32, activation='relu'))
CNNmodel.add(layers.Dense(24, activation='softmax'))
CNNmodel.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),metrics=['accuracy'])
CNNmodel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 126, 92, 32)       320
#
#  max_pooling2d_3 (MaxPooling  (None, 63, 46, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 63, 46, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 61, 44, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 22, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 30, 22, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 28, 20, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 10, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 14, 10, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 12, 8, 64)         36928
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 4, 64)         0
#  2D)
#
#  dropout_7 (Dropout)         (None, 6, 4, 64)          0
#
#  conv2d_8 (Conv2D)           (None, 4, 2, 64)          36928
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 64)                32832
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 165,304
# Trainable params: 165,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint("model.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=30, verbose=1, mode='auto')
model_history = CNNmodel.fit(np.array(train_set_spectorgram),np.array(train_labels),batch_size=32,epochs=100,validation_data=(np.array(val_set_spectorgram), np.array(val_labels)),callbacks=[checkpoint,early])
CNNmodel = load_model("model.h5")
score, acc = CNNmodel.evaluate(np.array(val_set_spectorgram), np.array(val_labels), verbose=0)
print('Val accuracy:', acc)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 155/155 [==============================] - ETA: 0s - loss: 2.1681 - accuracy: 0.1544
# Epoch 1: val_accuracy improved from -inf to 0.16475, saving model to model.h5
# 155/155 [==============================] - 3s 17ms/step - loss: 2.1681 - accuracy: 0.1544 - val_loss: 2.2034 - val_accuracy: 0.1648
# Epoch 2/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.8287 - accuracy: 0.1801
# Epoch 2: val_accuracy improved from 0.16475 to 0.19540, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 1.8288 - accuracy: 0.1797 - val_loss: 2.1219 - val_accuracy: 0.1954
# Epoch 3/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.8032 - accuracy: 0.1895
# Epoch 3: val_accuracy did not improve from 0.19540
# 155/155 [==============================] - 2s 14ms/step - loss: 1.8033 - accuracy: 0.1902 - val_loss: 2.0849 - val_accuracy: 0.1916
# Epoch 4/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.7510 - accuracy: 0.2306
# Epoch 4: val_accuracy improved from 0.19540 to 0.32950, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 1.7497 - accuracy: 0.2314 - val_loss: 1.8201 - val_accuracy: 0.3295
# Epoch 5/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.6260 - accuracy: 0.3190
# Epoch 5: val_accuracy improved from 0.32950 to 0.35632, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 1.6252 - accuracy: 0.3195 - val_loss: 1.7211 - val_accuracy: 0.3563
# Epoch 6/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.5515 - accuracy: 0.3617
# Epoch 6: val_accuracy improved from 0.35632 to 0.44828, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 1.5509 - accuracy: 0.3622 - val_loss: 1.4914 - val_accuracy: 0.4483
# Epoch 7/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.5096 - accuracy: 0.3697
# Epoch 7: val_accuracy did not improve from 0.44828
# 155/155 [==============================] - 2s 14ms/step - loss: 1.5083 - accuracy: 0.3696 - val_loss: 1.6099 - val_accuracy: 0.3525
# Epoch 8/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.4663 - accuracy: 0.4007
# Epoch 8: val_accuracy did not improve from 0.44828
# 155/155 [==============================] - 2s 14ms/step - loss: 1.4668 - accuracy: 0.4004 - val_loss: 1.4888 - val_accuracy: 0.4291
# Epoch 9/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.4339 - accuracy: 0.4161
# Epoch 9: val_accuracy did not improve from 0.44828
# 155/155 [==============================] - 2s 14ms/step - loss: 1.4341 - accuracy: 0.4161 - val_loss: 1.4491 - val_accuracy: 0.4368
# Epoch 10/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.4081 - accuracy: 0.4322
# Epoch 10: val_accuracy did not improve from 0.44828
# 155/155 [==============================] - 2s 14ms/step - loss: 1.4093 - accuracy: 0.4319 - val_loss: 1.4511 - val_accuracy: 0.4483
# Epoch 11/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.3920 - accuracy: 0.4465
# Epoch 11: val_accuracy did not improve from 0.44828
# 155/155 [==============================] - 2s 14ms/step - loss: 1.3929 - accuracy: 0.4460 - val_loss: 1.4061 - val_accuracy: 0.4291
# Epoch 12/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.3740 - accuracy: 0.4528
# Epoch 12: val_accuracy did not improve from 0.44828
# 155/155 [==============================] - 2s 14ms/step - loss: 1.3723 - accuracy: 0.4537 - val_loss: 1.4267 - val_accuracy: 0.4444
# Epoch 13/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.3396 - accuracy: 0.4647
# Epoch 13: val_accuracy improved from 0.44828 to 0.46743, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 1.3399 - accuracy: 0.4642 - val_loss: 1.3544 - val_accuracy: 0.4674
# Epoch 14/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.3216 - accuracy: 0.4773
# Epoch 14: val_accuracy improved from 0.46743 to 0.49808, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 1.3221 - accuracy: 0.4782 - val_loss: 1.3868 - val_accuracy: 0.4981
# Epoch 15/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.3026 - accuracy: 0.4865
# Epoch 15: val_accuracy did not improve from 0.49808
# 155/155 [==============================] - 2s 14ms/step - loss: 1.3007 - accuracy: 0.4867 - val_loss: 1.3036 - val_accuracy: 0.4828
# Epoch 16/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.2649 - accuracy: 0.4996
# Epoch 16: val_accuracy did not improve from 0.49808
# 155/155 [==============================] - 2s 14ms/step - loss: 1.2663 - accuracy: 0.4992 - val_loss: 1.2652 - val_accuracy: 0.4713
# Epoch 17/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.2495 - accuracy: 0.5145
# Epoch 17: val_accuracy did not improve from 0.49808
# 155/155 [==============================] - 2s 14ms/step - loss: 1.2513 - accuracy: 0.5133 - val_loss: 1.3070 - val_accuracy: 0.4713
# Epoch 18/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.2234 - accuracy: 0.5190
# Epoch 18: val_accuracy improved from 0.49808 to 0.50192, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 1.2215 - accuracy: 0.5200 - val_loss: 1.2831 - val_accuracy: 0.5019
# Epoch 19/100
# 152/155 [============================>.] - ETA: 0s - loss: 1.2005 - accuracy: 0.5366
# Epoch 19: val_accuracy did not improve from 0.50192
# 155/155 [==============================] - 2s 14ms/step - loss: 1.2006 - accuracy: 0.5358 - val_loss: 1.2223 - val_accuracy: 0.4943
# Epoch 20/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.1719 - accuracy: 0.5425
# Epoch 20: val_accuracy did not improve from 0.50192
# 155/155 [==============================] - 2s 14ms/step - loss: 1.1738 - accuracy: 0.5416 - val_loss: 1.2656 - val_accuracy: 0.4981
# Epoch 21/100
# 152/155 [============================>.] - ETA: 0s - loss: 1.1651 - accuracy: 0.5471
# Epoch 21: val_accuracy did not improve from 0.50192
# 155/155 [==============================] - 2s 14ms/step - loss: 1.1676 - accuracy: 0.5455 - val_loss: 1.2918 - val_accuracy: 0.4789
# Epoch 22/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.1578 - accuracy: 0.5549
# Epoch 22: val_accuracy improved from 0.50192 to 0.53640, saving model to model.h5
# 155/155 [==============================] - 2s 14ms/step - loss: 1.1574 - accuracy: 0.5546 - val_loss: 1.1813 - val_accuracy: 0.5364
# Epoch 23/100
# 152/155 [============================>.] - ETA: 0s - loss: 1.1365 - accuracy: 0.5633
# Epoch 23: val_accuracy did not improve from 0.53640
# 155/155 [==============================] - 2s 15ms/step - loss: 1.1370 - accuracy: 0.5627 - val_loss: 1.2417 - val_accuracy: 0.4866
# Epoch 24/100
# 152/155 [============================>.] - ETA: 0s - loss: 1.0961 - accuracy: 0.5738
# Epoch 24: val_accuracy did not improve from 0.53640
# 155/155 [==============================] - 2s 14ms/step - loss: 1.0975 - accuracy: 0.5742 - val_loss: 1.1798 - val_accuracy: 0.5019
# Epoch 25/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.0881 - accuracy: 0.5829
# Epoch 25: val_accuracy improved from 0.53640 to 0.55172, saving model to model.h5
# 155/155 [==============================] - 2s 14ms/step - loss: 1.0879 - accuracy: 0.5829 - val_loss: 1.1887 - val_accuracy: 0.5517
# Epoch 26/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.0624 - accuracy: 0.5915
# Epoch 26: val_accuracy did not improve from 0.55172
# 155/155 [==============================] - 2s 14ms/step - loss: 1.0630 - accuracy: 0.5916 - val_loss: 1.1888 - val_accuracy: 0.5249
# Epoch 27/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.0751 - accuracy: 0.5868
# Epoch 27: val_accuracy did not improve from 0.55172
# 155/155 [==============================] - 2s 14ms/step - loss: 1.0763 - accuracy: 0.5863 - val_loss: 1.1582 - val_accuracy: 0.5057
# Epoch 28/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.0472 - accuracy: 0.5966
# Epoch 28: val_accuracy did not improve from 0.55172
# 155/155 [==============================] - 2s 14ms/step - loss: 1.0477 - accuracy: 0.5964 - val_loss: 1.2399 - val_accuracy: 0.4904
# Epoch 29/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.0420 - accuracy: 0.5950
# Epoch 29: val_accuracy improved from 0.55172 to 0.56705, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 1.0422 - accuracy: 0.5952 - val_loss: 1.1366 - val_accuracy: 0.5670
# Epoch 30/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.0206 - accuracy: 0.6105
# Epoch 30: val_accuracy did not improve from 0.56705
# 155/155 [==============================] - 2s 14ms/step - loss: 1.0217 - accuracy: 0.6101 - val_loss: 1.1416 - val_accuracy: 0.5556
# Epoch 31/100
# 153/155 [============================>.] - ETA: 0s - loss: 1.0019 - accuracy: 0.6140
# Epoch 31: val_accuracy did not improve from 0.56705
# 155/155 [==============================] - 2s 14ms/step - loss: 1.0003 - accuracy: 0.6136 - val_loss: 1.1630 - val_accuracy: 0.5402
# Epoch 32/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.9913 - accuracy: 0.6138
# Epoch 32: val_accuracy improved from 0.56705 to 0.57854, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 0.9905 - accuracy: 0.6138 - val_loss: 1.0848 - val_accuracy: 0.5785
# Epoch 33/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.9573 - accuracy: 0.6373
# Epoch 33: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.9562 - accuracy: 0.6374 - val_loss: 1.1662 - val_accuracy: 0.5402
# Epoch 34/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.9637 - accuracy: 0.6258
# Epoch 34: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.9662 - accuracy: 0.6253 - val_loss: 1.1354 - val_accuracy: 0.5517
# Epoch 35/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.9482 - accuracy: 0.6375
# Epoch 35: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.9512 - accuracy: 0.6364 - val_loss: 1.1568 - val_accuracy: 0.5326
# Epoch 36/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.9269 - accuracy: 0.6469
# Epoch 36: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.9278 - accuracy: 0.6467 - val_loss: 1.1961 - val_accuracy: 0.5556
# Epoch 37/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.9269 - accuracy: 0.6522
# Epoch 37: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.9270 - accuracy: 0.6520 - val_loss: 1.1714 - val_accuracy: 0.5556
# Epoch 38/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.8866 - accuracy: 0.6575
# Epoch 38: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.8860 - accuracy: 0.6580 - val_loss: 1.2438 - val_accuracy: 0.5134
# Epoch 39/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.8890 - accuracy: 0.6636
# Epoch 39: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.8876 - accuracy: 0.6639 - val_loss: 1.2281 - val_accuracy: 0.5747
# Epoch 40/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.8700 - accuracy: 0.6710
# Epoch 40: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.8721 - accuracy: 0.6708 - val_loss: 1.1876 - val_accuracy: 0.5670
# Epoch 41/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.8410 - accuracy: 0.6814
# Epoch 41: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.8412 - accuracy: 0.6819 - val_loss: 1.1740 - val_accuracy: 0.5441
# Epoch 42/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.8513 - accuracy: 0.6708
# Epoch 42: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.8532 - accuracy: 0.6704 - val_loss: 1.1812 - val_accuracy: 0.5747
# Epoch 43/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.8602 - accuracy: 0.6726
# Epoch 43: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.8578 - accuracy: 0.6736 - val_loss: 1.1824 - val_accuracy: 0.5594
# Epoch 44/100
# 152/155 [============================>.] - ETA: 0s - loss: 0.8142 - accuracy: 0.6961
# Epoch 44: val_accuracy did not improve from 0.57854
# 155/155 [==============================] - 2s 14ms/step - loss: 0.8139 - accuracy: 0.6973 - val_loss: 1.1822 - val_accuracy: 0.5479
# Epoch 45/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.8136 - accuracy: 0.6916
# Epoch 45: val_accuracy improved from 0.57854 to 0.58621, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 0.8163 - accuracy: 0.6894 - val_loss: 1.2289 - val_accuracy: 0.5862
# Epoch 46/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.8234 - accuracy: 0.6871
# Epoch 46: val_accuracy did not improve from 0.58621
# 155/155 [==============================] - 3s 17ms/step - loss: 0.8218 - accuracy: 0.6880 - val_loss: 1.1838 - val_accuracy: 0.5824
# Epoch 47/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.7739 - accuracy: 0.7059
# Epoch 47: val_accuracy did not improve from 0.58621
# 155/155 [==============================] - 2s 14ms/step - loss: 0.7738 - accuracy: 0.7063 - val_loss: 1.3103 - val_accuracy: 0.5441
# Epoch 48/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.7450 - accuracy: 0.7108
# Epoch 48: val_accuracy improved from 0.58621 to 0.59770, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 0.7455 - accuracy: 0.7106 - val_loss: 1.2649 - val_accuracy: 0.5977
# Epoch 49/100
# 152/155 [============================>.] - ETA: 0s - loss: 0.7741 - accuracy: 0.7035
# Epoch 49: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.7757 - accuracy: 0.7035 - val_loss: 1.3788 - val_accuracy: 0.4981
# Epoch 50/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.7647 - accuracy: 0.7083
# Epoch 50: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.7633 - accuracy: 0.7090 - val_loss: 1.2558 - val_accuracy: 0.5824
# Epoch 51/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.7366 - accuracy: 0.7216
# Epoch 51: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.7377 - accuracy: 0.7213 - val_loss: 1.2733 - val_accuracy: 0.5709
# Epoch 52/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.7290 - accuracy: 0.7230
# Epoch 52: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.7283 - accuracy: 0.7233 - val_loss: 1.2250 - val_accuracy: 0.5670
# Epoch 53/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.7449 - accuracy: 0.7277
# Epoch 53: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.7433 - accuracy: 0.7280 - val_loss: 1.2422 - val_accuracy: 0.5670
# Epoch 54/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6960 - accuracy: 0.7398
# Epoch 54: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.6954 - accuracy: 0.7401 - val_loss: 1.2447 - val_accuracy: 0.5594
# Epoch 55/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.7105 - accuracy: 0.7328
# Epoch 55: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 15ms/step - loss: 0.7115 - accuracy: 0.7324 - val_loss: 1.2895 - val_accuracy: 0.5441
# Epoch 56/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6803 - accuracy: 0.7473
# Epoch 56: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.6827 - accuracy: 0.7460 - val_loss: 1.2747 - val_accuracy: 0.5632
# Epoch 57/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6833 - accuracy: 0.7510
# Epoch 57: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.6810 - accuracy: 0.7516 - val_loss: 1.3520 - val_accuracy: 0.5402
# Epoch 58/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6698 - accuracy: 0.7455
# Epoch 58: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.6702 - accuracy: 0.7454 - val_loss: 1.2718 - val_accuracy: 0.5785
# Epoch 59/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6882 - accuracy: 0.7412
# Epoch 59: val_accuracy did not improve from 0.59770
# 155/155 [==============================] - 2s 14ms/step - loss: 0.6912 - accuracy: 0.7407 - val_loss: 1.3200 - val_accuracy: 0.5824
# Epoch 60/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6594 - accuracy: 0.7508
# Epoch 60: val_accuracy improved from 0.59770 to 0.61303, saving model to model.h5
# 155/155 [==============================] - 2s 15ms/step - loss: 0.6596 - accuracy: 0.7502 - val_loss: 1.2699 - val_accuracy: 0.6130
# Epoch 61/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6578 - accuracy: 0.7563
# Epoch 61: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.6594 - accuracy: 0.7555 - val_loss: 1.2796 - val_accuracy: 0.5594
# Epoch 62/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6131 - accuracy: 0.7745
# Epoch 62: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.6116 - accuracy: 0.7751 - val_loss: 1.4521 - val_accuracy: 0.5517
# Epoch 63/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6403 - accuracy: 0.7602
# Epoch 63: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.6407 - accuracy: 0.7591 - val_loss: 1.2343 - val_accuracy: 0.5747
# Epoch 64/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5985 - accuracy: 0.7743
# Epoch 64: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5993 - accuracy: 0.7741 - val_loss: 1.2706 - val_accuracy: 0.5862
# Epoch 65/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6064 - accuracy: 0.7729
# Epoch 65: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.6040 - accuracy: 0.7734 - val_loss: 1.3117 - val_accuracy: 0.5556
# Epoch 66/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5996 - accuracy: 0.7753
# Epoch 66: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5993 - accuracy: 0.7755 - val_loss: 1.3471 - val_accuracy: 0.5824
# Epoch 67/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6034 - accuracy: 0.7761
# Epoch 67: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.6034 - accuracy: 0.7763 - val_loss: 1.3463 - val_accuracy: 0.5556
# Epoch 68/100
# 152/155 [============================>.] - ETA: 0s - loss: 0.5674 - accuracy: 0.7876
# Epoch 68: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5684 - accuracy: 0.7870 - val_loss: 1.3418 - val_accuracy: 0.5709
# Epoch 69/100
# 152/155 [============================>.] - ETA: 0s - loss: 0.5919 - accuracy: 0.7771
# Epoch 69: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.5952 - accuracy: 0.7749 - val_loss: 1.3910 - val_accuracy: 0.5670
# Epoch 70/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.6032 - accuracy: 0.7749
# Epoch 70: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.6018 - accuracy: 0.7753 - val_loss: 1.3455 - val_accuracy: 0.5632
# Epoch 71/100
# 152/155 [============================>.] - ETA: 0s - loss: 0.5736 - accuracy: 0.7880
# Epoch 71: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5734 - accuracy: 0.7880 - val_loss: 1.2994 - val_accuracy: 0.5556
# Epoch 72/100
# 152/155 [============================>.] - ETA: 0s - loss: 0.5577 - accuracy: 0.7901
# Epoch 72: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.5583 - accuracy: 0.7892 - val_loss: 1.3802 - val_accuracy: 0.5249
# Epoch 73/100
# 152/155 [============================>.] - ETA: 0s - loss: 0.5783 - accuracy: 0.7835
# Epoch 73: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5769 - accuracy: 0.7835 - val_loss: 1.3991 - val_accuracy: 0.5134
# Epoch 74/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5573 - accuracy: 0.7917
# Epoch 74: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5570 - accuracy: 0.7922 - val_loss: 1.4117 - val_accuracy: 0.5670
# Epoch 75/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5846 - accuracy: 0.7839
# Epoch 75: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5837 - accuracy: 0.7844 - val_loss: 1.4235 - val_accuracy: 0.5326
# Epoch 76/100
# 152/155 [============================>.] - ETA: 0s - loss: 0.5341 - accuracy: 0.8006
# Epoch 76: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.5336 - accuracy: 0.8009 - val_loss: 1.3746 - val_accuracy: 0.5441
# Epoch 77/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5222 - accuracy: 0.8007
# Epoch 77: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5246 - accuracy: 0.7997 - val_loss: 1.4088 - val_accuracy: 0.5287
# Epoch 78/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5240 - accuracy: 0.8025
# Epoch 78: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5247 - accuracy: 0.8025 - val_loss: 1.3920 - val_accuracy: 0.5211
# Epoch 79/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5053 - accuracy: 0.8160
# Epoch 79: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5059 - accuracy: 0.8157 - val_loss: 1.4431 - val_accuracy: 0.5594
# Epoch 80/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5139 - accuracy: 0.8141
# Epoch 80: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.5146 - accuracy: 0.8137 - val_loss: 1.3309 - val_accuracy: 0.5632
# Epoch 81/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5331 - accuracy: 0.8007
# Epoch 81: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.5318 - accuracy: 0.8013 - val_loss: 1.5071 - val_accuracy: 0.5326
# Epoch 82/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5054 - accuracy: 0.8074
# Epoch 82: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.5069 - accuracy: 0.8072 - val_loss: 1.4857 - val_accuracy: 0.5402
# Epoch 83/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.4926 - accuracy: 0.8088
# Epoch 83: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.4925 - accuracy: 0.8092 - val_loss: 1.4039 - val_accuracy: 0.5479
# Epoch 84/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.4800 - accuracy: 0.8221
# Epoch 84: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.4796 - accuracy: 0.8224 - val_loss: 1.4457 - val_accuracy: 0.5402
# Epoch 85/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.4996 - accuracy: 0.8158
# Epoch 85: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.4994 - accuracy: 0.8165 - val_loss: 1.6454 - val_accuracy: 0.5211
# Epoch 86/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.5013 - accuracy: 0.8113
# Epoch 86: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.5033 - accuracy: 0.8106 - val_loss: 1.5178 - val_accuracy: 0.5134
# Epoch 87/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.4568 - accuracy: 0.8337
# Epoch 87: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.4556 - accuracy: 0.8341 - val_loss: 1.5096 - val_accuracy: 0.5594
# Epoch 88/100
# 152/155 [============================>.] - ETA: 0s - loss: 0.4556 - accuracy: 0.8361
# Epoch 88: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.4554 - accuracy: 0.8363 - val_loss: 1.5819 - val_accuracy: 0.5670
# Epoch 89/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.4934 - accuracy: 0.8288
# Epoch 89: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 15ms/step - loss: 0.4935 - accuracy: 0.8288 - val_loss: 1.5475 - val_accuracy: 0.5517
# Epoch 90/100
# 153/155 [============================>.] - ETA: 0s - loss: 0.4636 - accuracy: 0.8354
# Epoch 90: val_accuracy did not improve from 0.61303
# 155/155 [==============================] - 2s 14ms/step - loss: 0.4651 - accuracy: 0.8347 - val_loss: 1.5094 - val_accuracy: 0.5441
# Epoch 90: early stopping
# Val accuracy: 0.6130267977714539

# %%
plt.plot(model_history.history['accuracy'], label='accuracy')
plt.plot(model_history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.savefig('Initial_Model_Accuracy.png')
plt.show()
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score, trainacc = CNNmodel.evaluate(np.array(train_set_spectorgram), np.array(train_labels), verbose=0)
y_pred = CNNmodel.predict(test_set_spectorgram)
report=metrics.classification_report(test_labels,np.argmax(y_pred,axis=1)) 
print(report)

matrix = metrics.confusion_matrix(test_labels ,np.argmax(y_pred,axis=1))
sns.heatmap(matrix, annot=True, fmt="d", cmap = 'rocket_r',xticklabels = ['SAD','ANGER','DISGUSTED','FEAR','HAPPY','NEUTRAL'],yticklabels = ['SAD','ANGER','DISGUSTED','FEAR','HAPPY','NEUTRAL'])
print(matrix)

print('val accuracy:', acc*100)
print('train accuracy:', trainacc*100)
print("test accuracy",metrics.accuracy_score(test_labels,np.argmax(y_pred,axis=1))*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.51       359
#            1       0.64      0.77      0.70       390
#            2       0.55      0.36      0.43       395
#            3       0.56      0.72      0.63       320
#            4       0.55      0.46      0.50       370
#            5       0.48      0.52      0.50       399
#
#     accuracy                           0.55      2233
#    macro avg       0.55      0.56      0.54      2233
# weighted avg       0.55      0.55      0.54      2233
#
# [[180   3  27  67   5  77]
#  [  0 299  29  12  32  18]
#  [ 60  70 142  46  35  42]
#  [ 27   7  15 232  21  18]
#  [ 13  65  22  33 170  67]
#  [ 70  23  24  28  47 207]]
# val accuracy: 61.302679777145386
# train accuracy: 89.95553851127625
# test accuracy 55.08284818629646
